# %%
import math

math.sin(10)
# Out:
# -0.5440211108893698

# %%
import pandas as pd
#
pd.DataFrame([1, 2, 3, 4])  # test pandas
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
df = pd.read_csv("pokemon_data.csv")
# df
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.columns   # display all headers
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
 # read excel file 
df = pd.read_excel("pokemon_data.xlsx")
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# read any text file with delimiter 
# text file with delimiter 

df = pd.read_csv("pokemon_data.txt", delimiter='\t')
df.head()
# df.tail()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# read each column 
df["Name"]  # Series single 

print(df["Name"][0]) # o nly Zero index
print(df["Name"][0:4]) # only Zero index 

print(df[['Name', "Type 1", "HP"]])
# Out:
# Bulbasaur
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# Name: Name, dtype: object
#                           Name    Type 1   HP
# 0                    Bulbasaur     Grass   45
# 1                      Ivysaur     Grass   60
# 2                     Venusaur     Grass   80
# 3        VenusaurMega Venusaur     Grass   80
# 4                   Charmander      Fire   39
# 5                   Charmeleon      Fire   58
# 6                    Charizard      Fire   78
# 7    CharizardMega Charizard X      Fire   78
# 8    CharizardMega Charizard Y      Fire   78
# 9                     Squirtle     Water   44
# 10                   Wartortle     Water   59
# 11                   Blastoise     Water   79
# 12     BlastoiseMega Blastoise     Water   79
# 13                    Caterpie       Bug   45
# 14                     Metapod       Bug   50
# 15                  Butterfree       Bug   60
# ...

# %%
# integer index based and label based location 

# iloc and loc

data = df.iloc[1]
print(data)  # series where all header became indexes 

data2 = df.iloc[1:4]  # with range
print(data2)
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
# read a specific loaction (R, C)

print(df.iloc[2, 1])
# Out:
# Venusaur

# %%
#index and raw 
for index, row in df.iterrows():
    if 'Charmander' in row['Name']:
        print(index)
# Out:
# 4

# %%
# data = df.loc[df["Type 1"] == "Grass"]
# print(data)
data = df.loc[df["HP"] < 50]
print(data)

# not work 
# iLocation based boolean indexing on an integer type is not available
# data_i = df.iloc[df["HP"] > 50]
# print(data_i)
# Out:
#        #                   Name    Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur     Grass  Poison  45      49       49
# 4      4             Charmander      Fire     NaN  39      52       43
# 9      7               Squirtle     Water     NaN  44      48       65
# 13    10               Caterpie       Bug     NaN  45      30       35
# 16    13                 Weedle       Bug  Poison  40      35       30
# 17    14                 Kakuna       Bug  Poison  45      25       50
# 20    16                 Pidgey    Normal  Flying  40      45       40
# 24    19                Rattata    Normal     NaN  30      56       35
# 26    21                Spearow    Normal  Flying  40      60       30
# 28    23                  Ekans    Poison     NaN  35      60       44
# 30    25                Pikachu  Electric     NaN  35      55       40
# 37    32         Nidoran (Male)    Poison     NaN  46      57       40
# ...

# %%
# ser = pd.Series([1, 2, 3])
# print(4 in ser)  # membership operators with series 


# describe all mathematically feature 
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# sorting

# sort df with name 
# df_namesort = df.sort_values("Name")  # ascending ordered 
df_namesort = df.sort_values("Name", ascending=False)  # descending ordered 
print(df_namesort)
# Out:
#        #                       Name    Type 1    Type 2   HP  Attack  Defense  \
# 510  460                  Abomasnow     Grass       Ice   90      92       75
# 511  460    AbomasnowMega Abomasnow     Grass       Ice   90     132      105
# 68    63                       Abra   Psychic       NaN   25      20       15
# 392  359                      Absol      Dark       NaN   65     130       60
# 393  359            AbsolMega Absol      Dark       NaN   65     150       60
# 678  617                   Accelgor       Bug       NaN   80      70       40
# 750  681       AegislashBlade Forme     Steel     Ghost   60     150       50
# 751  681      AegislashShield Forme     Steel     Ghost   60      50      150
# 153  142                 Aerodactyl      Rock    Flying   80     105       65
# 154  142  AerodactylMega Aerodactyl      Rock    Flying   80     135       85
# 332  306                     Aggron     Steel      Rock   70     110      180
# ...
